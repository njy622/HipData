# %% [markdown]
# ## Google BARD API
# - 프로그램 설치: conda activate base; pip install bardapi

# %%
import os, bardapi

# %%
with open('keys/bardApiKey.txt') as file:
    bard_key = file.read()
os.environ['_BARD_API_KEY'] = bard_key

# %%
user_input = '오늘 날씨를 알려주세요.'
response = bardapi.core.Bard().get_answer(user_input)
response
# Out:
# {'content': '오늘은 2023년 10월 17일 화요일입니다. 현재 시간은 2023년 10월 17일 15시 35분입니다. 현재 서울의 날씨는 흐리고, 기온은 13도입니다. 하늘은 흐려서 햇빛을 볼 수 없고, 비가 올 가능성이 있습니다. 기온은 낮 동안 15도까지 오르겠지만, 밤에는 5도까지 떨어질 것으로 예상됩니다. 바람은 약간 불겠고, 습도는 70%입니다.\n\n오늘의 날씨에 대비하여 우산을 준비하시는 것이 좋습니다. 또한, 야외 활동을 하실 때는 따뜻한 옷을 입으시는 것이 좋습니다.\n\n구체적인 날씨 예보는 다음과 같습니다.\n\n* 오전: 흐리고, 기온 13도, 강수확률 20%\n* 오후: 흐리고, 기온 15도, 강수확률 40%\n* 저녁: 흐리고, 기온 5도, 강수확률 40%\n* 밤: 흐리고, 기온 4도, 강수확률 20%\n\n오늘 하루도 즐겁게 보내시기 바랍니다.',
#  'conversation_id': 'c_34fccb15504e68bc',
#  'response_id': 'r_34fccb15504e6edf',
#  'factuality_queries': None,
#  'text_query': ['10월 17일 서울 날씨', 1],
#  'choices': [{'id': 'rc_34fccb15504e6d8e',
#    'content': ['오늘은 2023년 10월 17일 화요일입니다. 현재 시간은 2023년 10월 17일 15시 35분입니다. 현재 서울의 날씨는 흐리고, 기온은 13도입니다. 하늘은 흐려서 햇빛을 볼 수 없고, 비가 올 가능성이 있습니다. 기온은 낮 동안 15도까지 오르겠지만, 밤에는 5도까지 떨어질 것으로 예상됩니다. 바람은 약간 불겠고, 습도는 70%입니다.\n\n오늘의 날씨에 대비하여 우산을 준비하시는 것이 좋습니다. 또한, 야외 활동을 하실 때는 따뜻한 옷을 입으시는 것이 좋습니다.\n\n구체적인 날씨 예보는 다음과 같습니다.\n\n* 오전: 흐리고, 기온 13도, 강수확률 20%\n* 오후: 흐리고, 기온 15도, 강수확률 40%\n* 저녁: 흐리고, 기온 5도, 강수확률 40%\n* 밤: 흐리고, 기온 4도, 강수확률 20%\n\n오늘 하루도 즐겁게 보내시기 바랍니다.']},
#   {'id': 'rc_34fccb15504e63b1',
#    'content': ['오늘은 2023년 10월 17일 화요일입니다. 서울의 현재 시간은 2023년 10월 17일 15시 35분입니다. 현재 서울의 기온은 13도이고, 하늘은 맑습니다. 오늘 서울의 최고 기온은 20도, 최저 기온은 5도입니다. 오전에는 맑은 날씨가 이어지다가 오후에는 구름이 끼는 곳이 있을 것으로 예상됩니다. 저녁에는 비가 내릴 가능성이 있습니다.\n\n**날씨 요약**\n\n* 현재 기온: 13도\n* 현재 하늘 상태: 맑음\n* 최고 기온: 20도\n* 최저 기온: 5도\n* 구름: 오전에는 맑음, 오후에는 구름 끼는 곳 있음\n* 비: 저녁에 비 가능성 있음\n\n**옷차림**\n\n오늘은 쌀쌀한 날씨가 예상되므로, 가벼운 외투를 준비하는 것이 좋습니다. 또한, 비가 올 가능성도 있으므로 우산을 준비하는 것도 좋습니다.\n\n**활동 계획**\n\n오늘은 날씨가 맑은 오전에 야외 활동을 계획하는 것이 좋습니다. 오후에는 구름이 끼기 시작할 수 있으므로, 실내 활동을 계획하는 것도 고려해 볼 수 있습니다. 저녁에는 비가 올 가능성이 있으므로, 외출 계획을 미리 확인하는 것이 좋습니다.']},
#   {'id': 'rc_34fccb15504e69d4',
#    'content': ['오늘은 2023년 10월 17일 화요일입니다. 서울의 현재 시간은 2023년 10월 17일 15시 35분입니다. 서울의 현재 기온은 18도입니다. 하늘은 맑고, 바람은 약간 불고 있습니다.\n\n오늘 서울의 날씨는 다음과 같습니다.\n\n* 오전: 맑음, 기온 18~22도\n* 오후: 맑음, 기온 22~26도\n* 밤: 맑음, 기온 18~22도\n\n비나 눈이 내릴 가능성은 없습니다.\n\n옷차림은 가벼운 옷차림으로 하면 좋습니다.\n\n**세부 날씨**\n\n* 오전 9시: 기온 18도, 하늘 맑음, 바람 약간\n* 오전 12시: 기온 22도, 하늘 맑음, 바람 약간\n* 오후 3시: 기온 26도, 하늘 맑음, 바람 약간\n* 오후 6시: 기온 22도, 하늘 맑음, 바람 약간\n* 오후 9시: 기온 18도, 하늘 맑음, 바람 약간\n\n**주의 사항**\n\n* 오전에는 기온이 다소 낮을 수 있으므로, 따뜻한 옷차림을 하는 것이 좋습니다.\n* 오후에는 기온이 높아질 수 있으므로, 과로나 탈수를 조심해야 합니다.\n\n오늘 하루 즐거운 하루 보내세요!']}],
#  'links': [],
#  'images': [],
#  'program_lang': None,
#  'code': None,
#  'status_code': 200}

# %%
answer = response['content']
print(answer)
# Out:
# 오늘은 2023년 10월 17일 화요일입니다. 현재 시간은 2023년 10월 17일 15시 35분입니다. 현재 서울의 날씨는 흐리고, 기온은 13도입니다. 하늘은 흐려서 햇빛을 볼 수 없고, 비가 올 가능성이 있습니다. 기온은 낮 동안 15도까지 오르겠지만, 밤에는 5도까지 떨어질 것으로 예상됩니다. 바람은 약간 불겠고, 습도는 70%입니다.
#
# 오늘의 날씨에 대비하여 우산을 준비하시는 것이 좋습니다. 또한, 야외 활동을 하실 때는 따뜻한 옷을 입으시는 것이 좋습니다.
#
# 구체적인 날씨 예보는 다음과 같습니다.
#
# * 오전: 흐리고, 기온 13도, 강수확률 20%
# * 오후: 흐리고, 기온 15도, 강수확률 40%
# * 저녁: 흐리고, 기온 5도, 강수확률 40%
# * 밤: 흐리고, 기온 4도, 강수확률 20%
#
# 오늘 하루도 즐겁게 보내시기 바랍니다.
